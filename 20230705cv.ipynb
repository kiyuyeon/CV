# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import cv2
import sys

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print('Video open failed')
    sys.exit()

w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
fourcc = cv2.VideoWriter_fourcc(*'DIVX')


out = cv2.VideoWriter('review.avi',fourcc,fps,(w,h))

while True:
    ret, frame = cap.read()

    if not ret:
        print('Frame read failed')
        break
    ###########################################################
    edge = cv2.Canny(frame,50,150)
    edge_color=cv2.cvtColor(edge,cv2.COLOR_GRAY2BGR)
    ###########################################################
    out.write(edge_color)
    cv2.imshow('Frame', frame)
    cv2.imshow('edge', edge)
    
    if cv2.waitKey(20) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()

# %%
img = np.ones((600,1200,3))*255

cv2.line(img,(50,100),(300,120),(0,0,255),5,cv2.LINE_AA)
cv2.arrowedLine(img,(50,120),(300,140),(0,0,255),5,cv2.LINE_AA)
cv2.rectangle(img,(50,140),(300,300),(255,0,0,),5,cv2.LINE_AA)
cv2.rectangle(img,(70,160,210,120),(0,255,0),-1)
cv2.circle(img,(600,300),100,(123,56),10,cv2.LINE_AA)
cv2.ellipse(img,(600,300),(50,120),-20,0,360,(0,0,255),10,cv2.LINE_AA)
cv2.putText(img,'hello opencv',(600,200),cv2.FONT_HERSHEY_TRIPLEX,
            2,(0,0,255),1)

cv2.imshow('img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./Ch_2_fig/fig/cow.png')
dst = cv2.imread('./Ch_2_fig/fig/field.bmp')

src_gray = cv2.cvtColor(src,cv2.COLOR_BGR2GRAY)

h,w  = src.shape[:2]
dst_crop = dst[300:300+h,200:200+w]

ret, mask = cv2.threshold(src_gray,240,255,cv2.THRESH_BINARY_INV)
cv2.copyTo(src,mask,dst_crop)
cv2.imshow('src',src)
cv2.imshow('dst',dst)
cv2.imshow('mask',mask)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread('./Ch_2_fig/fig/airplane.bmp',cv2.IMREAD_COLOR)

if img is None:
    print('image read failed')
    sys.exit()


cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE)
cv2.imshow('img', img)

while True:
    if cv2.waitKey() == ord('q'):
        break
cv2.destroyAllWindows()

# %%
## 키보드 

img = cv2.imread('./Ch_2_fig/fig/puppy.bmp',cv2.IMREAD_GRAYSCALE)

img1 = img.copy()


cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE)
cv2.imshow('img', img)

while True:
    key = cv2.waitKey()
    if key == ord('q') or key==27:
        break
    elif key == ord('i'):
        img = 255-img
        cv2.imshow('img',img)
    elif key == ord('c'):
        img = cv2.Canny(img,50,100)
        cv2.imshow('img',img)
    elif key == ord('r'):
        img = img1.copy()
        cv2.imshow('img',img)
    elif key == ord('s'):
        cv2.imwrite('./Ch_2_fig/fig/ez.png',img)


        
cv2.destroyAllWindows()

# %%
import cv2
import sys

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print('Video open failed')
    sys.exit()

f_flage = False
e_flage = False

while True:
    ret, frame = cap.read()

    if not ret:
        print('Frame read failed')
        break    
    
    key = cv2.waitKey(20)

    if key == 27:
        break
    if f_flage:
        frame = cv2.flip(frame,1)
        cv2.imshow('image', frame)
    if e_flage:
        frame = cv2.Canny(frame,50,150)

    cv2.imshow('Frame', frame)

    if key == ord('q'):
        break
    elif key == ord('f'):
        f_flage = not f_flage
    elif key == ord('e'):
        e_flage = not e_flage

cv2.destroyAllWindows()
cap.release()

# %%
def call_mouse(event,x,y,flags,param):
    global oldx,oldy

    if event == cv2.EVENT_LBUTTONDOWN:
        oldx , oldy = x,y

    # elif event == cv2.EVENT_LBUTTONUP:
    #     print('BUTTONUP : x, y ',x,y)

    elif event == cv2.EVENT_MOUSEMOVE:
        if flags == cv2.EVENT_LBUTTONDOWN:
            cv2.line(img,(oldx,oldy),(x,y),(0,255,0),10,cv2.LINE_AA)
            cv2.imshow('img',img)
            oldx,oldy = x,y

img = np.ones((600,600,3),np.uint8)*255
cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE)
cv2.imshow('img',img)


while True:
    key = cv2.waitKey()
    if key == 27:
        break
    elif key == ord('s'):
        cv2.imwrite('./Ch_2_fig/fig/ze.png',img)
    elif key == ord('w'):
        cv2.setMouseCallback('img',call_mouse)
    elif key == ord(' '):
        img = np.ones((600,600,3),np.uint8)*255
        cv2.imshow('img',img)
            



cv2.waitKey()
cv2.destroyAllWindows()
