# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices("GPU")
print("사용 가능한 GPU 장치:")
for device in physical_devices:
    print(device)

import cv2
import numpy as np
import sys
print('\n',cv2.__version__)
# Out:
# 사용 가능한 GPU 장치:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
#
#  4.7.0

# %%
img = cv2.imread('./Ch_1_fig/fig/cat.bmp',cv2.IMREAD_COLOR)
# print('img shape = ',img.shape)
# print('img type = ',img.dtype)
h , w = img.shape[:2]

# cv2.imwrite('./Ch_1_fig/fig/resize_hw.png',img_resize)

img_resize = cv2.resize(img,(w//2,h//2))

if img is None:
    print('image read failded')
    sys.exit()

cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE) 
cv2.imshow('img',img)

while True:
    if cv2.waitKey() == ord('q'):
        break

cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

img_BGR = cv2.imread('./Ch_1_fig/fig/cat.bmp')
img_RGB = cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
img_GRAY = cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

fig ,ax =plt.subplots(1,3,figsize=(12,5))

ax[0].imshow(img_BGR),ax[0].axis('off'),ax[0].set_title('BGR')
ax[1].imshow(img_RGB),ax[1].axis('off'),ax[1].set_title('RGB')
ax[2].imshow(img_GRAY,cmap='gray'),ax[2].axis('off'),ax[2].set_title('GRAY')

plt.show()

# %%
import os 
import glob
# path_lists = []
# paths = os.listdir('./Ch_1_fig/fig/images/')
# # print(paths)
# for i in paths:
#     path_list = './Ch_1_fig/fig/images/'+ i
#     path_lists.append(path_list)

path_lists = glob.glob('./Ch_1_fig/fig/my_images/*.jpg')

print(path_lists)


cv2.namedWindow('scene',cv2.WINDOW_NORMAL)
cv2.setWindowProperty('scene',cv2.WND_PROP_FULLSCREEN,cv2.WINDOW_FULLSCREEN)

idx=0
while True:
    img = cv2.imread(path_lists[idx])

    if img is None:
        continue

    cv2.imshow('scene',img)

    if cv2.waitKey(30)==27:
        break

    idx += 1

    if idx >=len(path_lists):
        idx=0

cv2.destroyAllWindows()
# Out:
# ['./Ch_1_fig/fig/my_images\\annie-spratt-cLMLc76RA8E-unsplash.jpg', './Ch_1_fig/fig/my_images\\annie-spratt-fl88zgYk-g8-unsplash.jpg', './Ch_1_fig/fig/my_images\\annie-spratt-fUE29IBWtRA-unsplash.jpg', './Ch_1_fig/fig/my_images\\krisjanis-kazaks-xs9W09cG_ec-unsplash.jpg', './Ch_1_fig/fig/my_images\\kristin-todorova-sh2opZ3V3PU-unsplash.jpg', './Ch_1_fig/fig/my_images\\marina-t-8YLWA6_2uGY-unsplash.jpg', './Ch_1_fig/fig/my_images\\marina-t-CBqnpgZTvkA-unsplash.jpg', './Ch_1_fig/fig/my_images\\marina-t-pQg4GTuzwXw-unsplash.jpg', './Ch_1_fig/fig/my_images\\markus-spiske-ICz-bypJlzI-unsplash.jpg', './Ch_1_fig/fig/my_images\\nick-page-Opx9C9GPU3Q-unsplash.jpg']

# %%
img = cv2.imread('./Ch_2_fig/fig/puppy.bmp')
print(f'shape =' ,img.shape)

h,w = img.shape[:2]
x = w//2
y = h//2
# print('center value = ',img[x,y])

img [159:239,250:500] = 0,0,0

# h, w = img.shape[:2]
# x = w // 2
# y = h // 2
# img[y-75:y, x-75:x+175] = [0, 0, 0]


if img is None :
    print('image read failed')
    sys.exit()
# cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE)
cv2.imshow('img',img)
# w,y,w,h = cv2.selectROI('img',img)
# print(w,y,w,h)
while True:
    if cv2.waitKey() == 27:
        break

cv2.destroyAllWindows()
# Out:
# shape = (480, 640, 3)

# %%
# 영상 생성

img1 = np.zeros((400,600,3),dtype=np.uint8)
# img2 = np.zeros((400,600),dtype=np.uint8)
img2 = np.ones((400,600),dtype=np.uint8)*255
img3 = np.full((400,600,3),(255,0,255),np.uint8)

cv2.imshow('img1',img1)
cv2.imshow('img2',img2)
cv2.imshow('img3',img3)



cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 영상 복사

img = cv2.imread('./Ch_2_fig/fig/puppy.bmp',cv2.IMREAD_COLOR)

img1 = img
img2 = img.copy()
img[50:100,100:300]=0,255,128

if img is None:
    print('image read failed')
    sys.exit
cv2.namedWindow('img',cv2.WINDOW_AUTOSIZE)
cv2.imshow('img',img)
cv2.imshow('img1',img1)
cv2.imshow('img2',img2)
while True:
    if cv2.waitKey() == 27:
        break


cv2.destroyAllWindows()

# %%
img = cv2.imread('./Ch_2_fig/fig/puppy.bmp',cv2.IMREAD_COLOR)

img1 = img[200:400,300:500]
img2 = img[200:400,300:500].copy()

#
cv2.circle(img1,(100,100),50,(0,0,255),4,cv2.LINE_AA)
cv2.circle(img2,(100,100),50,(255,0,0),-1)

cv2.imshow('img',img)
cv2.imshow('img1',img1)
cv2.imshow('img2',img2)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
img = cv2.imread('./Ch_2_fig/fig/rudolf.png',cv2.IMREAD_COLOR)

img1 = img[400:700,400:700]
img2 = img[400:700,400:700].copy()

#
cv2.circle(img1,(100,110),60,(0,0,255),-1)

cv2.imshow('img',img)
cv2.imshow('img1',img1)
cv2.imshow('img2',img2)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./Ch_2_fig/fig/airplane.bmp',cv2.IMREAD_COLOR)
mask = cv2.imread('./Ch_2_fig/fig/mask_plane.bmp',cv2.IMREAD_GRAYSCALE)
dst = cv2.imread('./Ch_2_fig/fig/field.bmp')

if src is None or mask is None or dst is None:
    print('image read failed')
    sys.exit()

cv2.copyTo(src,mask,dst)

# dst = cv2.copyTo(src,mask)

# dst[mask>0] = src[mask>0] 

dst[mask>0] = (0,0,255)


cv2.imshow('src',src)
cv2.imshow('mask',mask)
cv2.imshow('dst',dst)


cv2.waitKey()
cv2.destroyAllWindows()
